# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8) # adjust the configurations of plots we create

#Read in the data 


df=pd.read_csv('/Users/mankomalsohi/Desktop/movies.csv')

# %%
#Lets look at the data 
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Checking for nulls in the dataset

for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Replace nulls with 0 for data cleaning

for col in df.columns:
    df[col].fillna(0, inplace=True)

# %%
# To check if there is any null value left 
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data type of columns
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
 df['yearcorrect'] = df['released'].astype(str).str.split().str[2]

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
#Scatter plot with budget and gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title("Budget vs Gross earnings")
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')

plt.show()

# %%
# Plot the Budget vs Gross using seaborn
sns.regplot(x='budget', y='gross',data=df, scatter_kws={"color":"green"},line_kws={"color":"brown"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
df.corr(method='kendall',numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.066796  0.330410  0.209304  0.216595  0.096390
# score    0.066796  1.000000  0.300673 -0.004843  0.091331  0.283601
# votes    0.330410  0.300673  1.000000  0.439883  0.560449  0.197697
# budget   0.209304 -0.004843  0.439883  1.000000  0.541956  0.176184
# gross    0.216595  0.091331  0.560449  0.541956  1.000000  0.177429
# runtime  0.096390  0.283601  0.197697  0.176184  0.177429  1.000000

# %%
# There is a High correlation between budget and gross.

correlation_matrix=df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation matric for Numeric features")
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized=df

for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype=='object':
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#                                                 name  rating  genre  year  \
# 0                                        The Shining       7      6  1980
# 1                                    The Blue Lagoon       7      1  1980
# 2     Star Wars: Episode V - The Empire Strikes Back       5      0  1980
# 3                                          Airplane!       5      4  1980
# 4                                         Caddyshack       7      4  1980
# ...                                              ...     ...    ...   ...
# 7663                                    More to Life       0      6  2020
# 7664                                     Dream Round       0      4  2020
# 7665                                   Saving Mbango       0      6  2020
# 7666                                    It's Just Us       0      6  2020
# 7667                                       Tee em el       0     10  2020
#
#       released  score      votes  director  writer  star  country    budget  \
# ...

# %%
correlation_matrix_2=df_numerized.corr(numeric_only=True)
sns.heatmap(correlation_matrix_2, annot=True)
plt.title("Correlation matric for Numeric features")
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
corr_matrix=df_numerized.corr(numeric_only=True)

corr_matrix.unstack()
# Out:
# rating       rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score          0.006192
#                               ...
# yearcorrect  budget         0.300649
#              gross          0.254946
#              company       -0.011060
#              runtime        0.120915
#              yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
corr_matrix=df_numerized.corr(numeric_only=True)
corr_pairs=corr_matrix.unstack()
print(corr_pairs)
# Out:
# rating       rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score          0.006192
#                               ...
# yearcorrect  budget         0.300649
#              gross          0.254946
#              company       -0.011060
#              runtime        0.120915
#              yearcorrect    1.000000
# Length: 225, dtype: float64
